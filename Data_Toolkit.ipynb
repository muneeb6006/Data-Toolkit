# %% [markdown]
# **THEORY**

# %%
#1 What is numpy and why is it widely used in python?
'''numpy is a python library for numerical computing;its fast and efficient for array operations and math'''
# Out:
# 'numpy is a python library for numerical computing;its fast and efficient for array operations and math'

# %%
#2 How does broadcasting work in numpy?
'''broadcasting allows numpy to perform operations on arrays of different shapes by automatically expanding dimensions'''
# Out:
# 'broadcasting allows numpy to perform operations on arrays of different shapes by automatically expanding dimensions'

# %%
#3 what is pandas dataframe?
''' A pandas dataframe is a 2-dimensional labeled data structure with columns of potentially different types.'''
# Out:
# ' A pandas dataframe is a 2-dimensional labeled data structure with columns of potentially different types.'

# %%
#4 explain the use of the groupby() methods in pandas?
'''groupby() splits data into groups,applies functions, and combines results'''
# Out:
# 'groupby() splits data into groups,applies functions, and combines results'

# %%
#5 why is seaborn prefered for stastical visualisations?
'''seaborn is preferred because it provides attractive, easy to use stastical plots built on matplotlib'''
# Out:
# 'seaborn is preferred because it provides attractive, easy to use stastical plots built on matplotlib'

# %%
#6 what are the diffrence between numpy  arrays and python lists?
'''numpy arrays are faster and more memory efficient than python lists,and also fixed type and support vectorized operations'''
# Out:
# 'numpy arrays are faster and more memory efficient than python lists,and also fixed type and support vectorized operations'

# %%
#7what is a heatmap and when should it be used?
''' a heatmap shows data values using colors; useful for corelations, matrices or patterns'''
# Out:
# ' a heatmap shows data values using colors; useful for corelations, matrices or patterns'

# %%
#8what does the term vectorized operation mean in numpy?
''' a vectorized operation applies operations to entire arrays without explicit loops, making code faster'''
# Out:
# ' a vectorized operation applies operations to entire arrays without explicit loops, making code faster'

# %%
#9 how does matplotlib differ from plotly?
'''matplotlib is a static and low level;plotly is interactive and web friendly'''
# Out:
# 'matplotlib is a static and low level;plotly is interactive and web friendly'

# %%
#10 what is the significance of hierarchical indexing in pandas?
''' hierarchical indexing allows multiple levels of indexing on a single axis'''
# Out:
# ' hierarchical indexing allows multiple levels of indexing on a single axis'

# %%
#11 what is the role of seaborn pairlot() function?
'''pairlot() visualizes pairwise relationships between variables and distribution'''
# Out:
# 'pairlot() visualizes pairwise relationships between variables and distribution'

# %%
#12 what is purpose of describe() function in pandas?
'''describe() provides summary statistics for numerical columns'''
# Out:
# 'describe() provides summary statistics for numerical columns'

# %%
#13 why is  handling missing data important in pandas.?
'''handling missing data is important to ensure accurate analysis and prevent errors'''
# Out:
# 'handling missing data is important to ensure accurate analysis and prevent errors'

# %%
#14 what are the benefits of using plotly  for data visualization?
'''plotly offers interactive ,dynamic and web ready visualization'''
# Out:
# 'plotly offers interactive ,dynamic and web ready visualization'

# %%
#15 how does numpy handles multidimensional arrays?
'''numpy handles multidimensional arrays using ndarrays with multiple axes and dimensions'''
# Out:
# 'numpy handles multidimensional arrays using ndarrays with multiple axes and dimensions'

# %%
#16 what is the role of bokeh in data visualization?
'''bokeh is used to create interactive and web based visualization'''
# Out:
# 'bokeh is used to create interactive and web based visualization'

# %%
#17 explain the difference in apply() and map() in pandas?
'''apply() works on rows or columns of a dataframe;map() works on a single series'''
# Out:
# 'apply() works on rows or columns of a dataframe;map() works on a single series'

# %%
#18 what are the some advance features of numpy?
'''advanced numpy features include broadcasting,linear algebra,FFT and advanced indexing'''
# Out:
# 'advanced numpy features include broadcasting,linear algebra,FFT and advanced indexing'

# %%
#19 How does panda simplify time series analysis?
'''pandas simplifies time series with data indexing,resampling ,rolling windows and time based slicing'''
# Out:
# 'pandas simplifies time series with data indexing,resampling ,rolling windows and time based slicing'

# %%
#20 what is role of pivot table in pandas?
'''a pivot table summarizes data by aggregating and grouping'''
# Out:
# 'a pivot table summarizes data by aggregating and grouping'

# %%
#21 why is numpy's array slicing faster than python list slicing?
'''numpy slicing is faster because it works on contigious memory and uses low-level optimized code'''
# Out:
# 'numpy slicing is faster because it works on contigious memory and uses low-level optimized code'

# %%
#22 what  are some common use case of seaborn?
'''visualizing data distribution,showing relationship between variables, creating heatmaps,comparing categories with box violin plots'''
# Out:
# 'visualizing data distribution,showing relationship between variables, creating heatmaps,comparing categories with box violin plots'

# %% [markdown]
# # **PRACTICAL**

# %%
#1 How do you create a 2d numpy array and calculate the sum of each row?
'''import numpy as np
arr = np.array([[1,2,3],[4,5,6,]])
row_sums=arr.sum(axis=1)
print(row_sums)'''
# Out:
# 'import numpy as np\narr = np.array([[1,2,3],[4,5,6,]])\nrow_sums=arr.sum(axis=1)\nprint(row_sums)'

# %%
#2 write a panda script to find a mean of the specific column in a dataframe?
'''import pandas as pd
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
mean_B=df['B'].mean()
print(mean_B)'''
# Out:
# "import pandas as pd\ndf=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})\nmean_B=df['B'].mean()\nprint(mean_B)"

# %%
#3  create a scatter plot using matplotlib?
'''import matplotlib.pyplot as plt
x=[1,2,3]
y=[4,5,6]
plt.scatter(x,y)
plt.show()'''
# Out:
# 'import matplotlib.pyplot as plt\nx=[1,2,3]\ny=[4,5,6]\nplt.scatter(x,y)\nplt.show()'

# %%
#4 how do u calculate the correlation of matrix using seaborn and visualize it with heatmap?
'''import seaborn as sns
import matplotlib.pyplot as plt
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6],'C':[7,8,9]})
corr=df.corr()
sns.heatmap(corr,annot=True)'''
# Out:
# "import seaborn as sns\nimport matplotlib.pyplot as plt\ndf=pd.DataFrame({'A':[1,2,3],'B':[4,5,6],'C':[7,8,9]})\ncorr=df.corr()\nsns.heatmap(corr,annot=True)"

# %%
#5 generate a bar plot using plotly?
'''import plotly.express as px
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
fig=px.bar(df,x='A',y='B')
fig.show()'''
# Out:
# "import plotly.express as px\ndf=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})\nfig=px.bar(df,x='A',y='B')\nfig.show()"

# %%
#6 create a dataframe and add a new column based on an existing column?
'''import pandas as pd
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df['C']=df['A']+df['B']
print(df)'''
# Out:
# "import pandas as pd\ndf=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})\ndf['C']=df['A']+df['B']\nprint(df)"

# %%
#7 write a program to perform element wise multiplication of two numpy arrays?
'''import numpy as np
arr1=np.array([1,2,3])
arr2=np.array([4,5,6])
result=arr1*arr2
print(result)'''
# Out:
# 'import numpy as np\narr1=np.array([1,2,3])\narr2=np.array([4,5,6])\nresult=arr1*arr2\nprint(result)'

# %%
#8 create a line plot with multiple lines using matplottlib?
'''import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6]),label='line1'
plt.plot([1,2,3],[7,8,9]),label='line2'
plt.legend()
plt.show()'''
# Out:
# "import matplotlib.pyplot as plt\nplt.plot([1,2,3],[4,5,6]),label='line1'\nplt.plot([1,2,3],[7,8,9]),label='line2'\nplt.legend()\nplt.show()"

# %%
#9generate a pandas dataframe and filter rows where a column value is greater than the thereshold?
'''import pandas as pd
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
threshold=
filtered_df=df[df['A']>threshold]
print(filtered_df)'''
# Out:
# "import pandas as pd\ndf=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})\nthreshold=\nfiltered_df=df[df['A']>threshold]\nprint(filtered_df)"

# %%
#10 create a histrogram using using seaborn to visualize a distribution?
'''import seaborn as sns
import matplotlib.pyplot as plt
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
sns.histplot(df['A'])
plt.show()'''

#
# Out:
# "import seaborn as sns\nimport matplotlib.pyplot as plt\ndf=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})\nsns.histplot(df['A'])\nplt.show()"

# %%
#11  perfrom matrix multiplication using numpy?
'''import numpy as np
arr1=np.array([[1,2],[3,4]])
arr2=np.array([[5,6],[7,8]])
result=np.(dot(arr1,arr2)
print(result)'''
# Out:
# 'import numpy as np\narr1=np.array([[1,2],[3,4]])\narr2=np.array([[5,6],[7,8]])\nresult=np.(dot(arr1,arr2)\nprint(result)'

# %%
#12 use pandas to load a CSV file and display its first five rows?
'''import pandas as pd
df=pd.read_csv('data.csv')
print(df.head())'''
# Out:
# "import pandas as pd\ndf=pd.read_csv('data.csv')\nprint(df.head())"

# %%
#13 create a 3d scatter plot using plotly?
'''import plotly.express as px
fig=px.scatter
df=pd.DataFrame({'x':[1,2,3],'y':[4,5,6],'z':[7,8,9]})
fig.show()'''
# Out:
# "import plotly.express as px\nfig=px.scatter\ndf=pd.DataFrame({'x':[1,2,3],'y':[4,5,6],'z':[7,8,9]})\nfig.show()"
